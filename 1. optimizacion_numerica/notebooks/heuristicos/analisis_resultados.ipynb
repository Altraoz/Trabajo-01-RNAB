# %% [markdown]
# # Analisis de resultados heuristicos
#
# Este notebook consume los datos generados por `generador_de_datos.ipynb` y organiza la parte analitica de la entrega.
#
# Objetivos de este notebook:
# - calcular medias, desviaciones y mejores/peores casos
# - comparar metodos por funcion y dimension
# - analizar costo en evaluaciones, no solo valor final
# - producir tablas y figuras listas para el reporte

# %%
import json
from pathlib import Path

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

def find_project_dir(start: Path | None = None) -> Path:
    current = (start or Path.cwd()).resolve()
    for candidate in [current, *current.parents]:
        if candidate.name == "1. optimizacion_numerica" and (candidate / "functions").exists():
            return candidate
    raise FileNotFoundError("No se pudo ubicar la carpeta 1. optimizacion_numerica.")


BASE_DIR = Path.cwd()
PROJECT_DIR = find_project_dir(BASE_DIR)
DATA_DIR = PROJECT_DIR / "assets" / "heuristicos" / "datos"
FIGURES_DIR = PROJECT_DIR / "assets" / "heuristicos" / "images"
MANIFEST_PATH = DATA_DIR / "manifest_heuristicos.json"

if not DATA_DIR.exists():
    raise FileNotFoundError("No se encontro la carpeta datos dentro de heuristicos.")

if not MANIFEST_PATH.exists():
    raise FileNotFoundError("No se encontro manifest_heuristicos.json. Ejecuta primero generador_de_datos.ipynb.")

FIGURES_DIR.mkdir(parents=True, exist_ok=True)

with MANIFEST_PATH.open("r", encoding="utf-8") as file:
    manifest = json.load(file)

manifest
# Out:
# {'modulo': 'heuristicos',
#  'funciones': ['rosenbrock',
#   'rastrigin',
#   'schwefel',
#   'griewank',
#   'goldstein_price',
#   'six_hump_camel'],
#  'metodos': ['ea', 'pso', 'de'],
#  'consumer_notebook': 'analisis_resultados.ipynb',
#  'descripcion': 'Datos generados sin graficas ni animaciones.',
#  'fecha_referencia': '2026-07-24',
#  'filtros_ejecucion': {'selected_functions': ['rosenbrock'],
#   'selected_dimensions': None,
#   'selected_methods': None,
#   'selected_n_corridas': None,
#   'skip_existing_files': True},
#  'directorios': {'datos_base': 'assets/heuristicos/datos'},
#  'organizacion_corridas': 'assets/heuristicos/datos/<funcion>/<archivo>.json|csv',
#  'organizacion_resumenes': 'assets/heuristicos/datos/<funcion>/resumen_<funcion>.json|csv',
#  'campos_corridas': ['funcion',
#   'nombre_funcion',
#   'corrida',
#   'semilla',
#   'metodo',
#   'nombre_metodo',
#   'dimension',
#   'limites',
#   'optimo_conocido',
#   'mejor_solucion',
#   'mejor_valor',
#   'distancia_al_optimo',
#   'iteraciones',
#   'evaluaciones',
#   'best_values_history',
#   'parametros'],
#  'campos_resumen': ['funcion',
#   'nombre_funcion',
#   'metodo',
#   'nombre_metodo',
#   'dimension',
#   'n_corridas',
#   'mejor_valor',
#   'peor_valor',
#   'promedio_valor',
#   'mediana_valor',
#   'desviacion_valor',
#   'mejor_distancia_al_optimo',
#   'promedio_distancia_al_optimo',
#   'promedio_evaluaciones',
#   'mediana_evaluaciones',
#   'promedio_iteraciones',
#   'mediana_iteraciones']}

# %% [markdown]
# ## Carga de datos

# %%
run_csv_files = sorted(path for path in DATA_DIR.glob("*/*.csv") if not path.name.startswith("resumen_"))
summary_csv_files = sorted(DATA_DIR.glob("*/resumen_*.csv"))
run_json_files = sorted(path for path in DATA_DIR.glob("*/*.json") if not path.name.startswith("resumen_"))

if not run_csv_files:
    raise FileNotFoundError("No se encontraron archivos de corridas dentro de datos/<funcion>/. Ejecuta primero el generador.")

runs_df = pd.concat((pd.read_csv(path) for path in run_csv_files), ignore_index=True)

if summary_csv_files:
    summary_df = pd.concat((pd.read_csv(path) for path in summary_csv_files), ignore_index=True)
else:
    summary_df = pd.DataFrame()

print("Archivos de corridas encontrados:", len(run_csv_files))
print("Archivos de resumen encontrados:", len(summary_csv_files))
runs_df.head()
# Out:
# Archivos de corridas encontrados: 90
# Archivos de resumen encontrados: 6
#            funcion   nombre_funcion  corrida  semilla metodo  \
# 0  goldstein_price  Goldstein-Price        1     2111     de
# 1  goldstein_price  Goldstein-Price        2     2112     de
# 2  goldstein_price  Goldstein-Price        3     2113     de
# 3  goldstein_price  Goldstein-Price        4     2114     de
# 4  goldstein_price  Goldstein-Price        5     2115     de
#
#            nombre_metodo  dimension      limites optimo_conocido  \
# 0  Evolucion diferencial          2  [-2.0, 2.0]     [0.0, -1.0]
# 1  Evolucion diferencial          2  [-2.0, 2.0]     [0.0, -1.0]
# 2  Evolucion diferencial          2  [-2.0, 2.0]     [0.0, -1.0]
# 3  Evolucion diferencial          2  [-2.0, 2.0]     [0.0, -1.0]
# 4  Evolucion diferencial          2  [-2.0, 2.0]     [0.0, -1.0]
#
#                                   mejor_solucion  mejor_valor  \
# 0  [-1.941326458776844e-09, -1.0000000003607747]          3.0
# 1   [9.907654301167131e-10, -0.9999999937771327]          3.0
# 2   [5.007355819994268e-09, -1.0000000014030788]          3.0
# 3   [2.560481454526774e-09, -0.9999999989957529]          3.0
# 4   [4.535914836510655e-10, -1.0000000033279302]          3.0
#
#    distancia_al_optimo  iteraciones  evaluaciones  \
# 0         1.974565e-09          120          4840
# 1         6.301245e-09          120          4840
# 2         5.200216e-09          120          4840
# 3         2.750378e-09          120          4840
# 4         3.358700e-09          120          4840
#
#                                  best_values_history  \
# 0  [27.436804075112295, 27.436804075112295, 12.88...
# 1  [85.93904882354973, 54.920942532148274, 45.881...
# 2  [34.834108476994736, 14.055624583609243, 14.05...
# 3  [5.07186596678872, 5.07186596678872, 5.0718659...
# 4  [54.46087322379173, 29.101133470657263, 22.779...
#
#                                           parametros
# 0  {"crossover_rate": 0.7, "max_iterations": 120,...
# 1  {"crossover_rate": 0.7, "max_iterations": 120,...
# 2  {"crossover_rate": 0.7, "max_iterations": 120,...
# 3  {"crossover_rate": 0.7, "max_iterations": 120,...
# 4  {"crossover_rate": 0.7, "max_iterations": 120,...

# %%
numeric_columns = [
    "corrida",
    "semilla",
    "dimension",
    "mejor_valor",
    "distancia_al_optimo",
    "iteraciones",
    "evaluaciones",
]

for column in numeric_columns:
    runs_df[column] = pd.to_numeric(runs_df[column], errors="coerce")

runs_df = runs_df.dropna(subset=["dimension"]).copy()
runs_df["dimension"] = runs_df["dimension"].astype(int)

runs_df["caso"] = runs_df["nombre_funcion"] + " " + runs_df["dimension"].astype(str) + "D"
runs_df["eficiencia_valor_por_eval"] = runs_df["mejor_valor"] / runs_df["evaluaciones"].replace(0, np.nan)

if summary_df.empty:
    summary_df = (
        runs_df.groupby(["funcion", "nombre_funcion", "metodo", "nombre_metodo", "dimension"], dropna=False)
        .agg(
            n_corridas=("corrida", "count"),
            mejor_valor=("mejor_valor", "min"),
            peor_valor=("mejor_valor", "max"),
            promedio_valor=("mejor_valor", "mean"),
            mediana_valor=("mejor_valor", "median"),
            desviacion_valor=("mejor_valor", "std"),
            mejor_distancia_al_optimo=("distancia_al_optimo", "min"),
            promedio_distancia_al_optimo=("distancia_al_optimo", "mean"),
            promedio_evaluaciones=("evaluaciones", "mean"),
            mediana_evaluaciones=("evaluaciones", "median"),
            promedio_iteraciones=("iteraciones", "mean"),
            mediana_iteraciones=("iteraciones", "median"),
        )
        .reset_index()
    )
    summary_df["desviacion_valor"] = summary_df["desviacion_valor"].fillna(0.0)

summary_df["caso"] = summary_df["nombre_funcion"] + " " + summary_df["dimension"].astype(int).astype(str) + "D"
summary_df["caso_n"] = summary_df["caso"] + " | n=" + summary_df["n_corridas"].astype(int).astype(str)
summary_df = summary_df.sort_values(["nombre_funcion", "dimension", "n_corridas", "metodo"]).reset_index(drop=True)
ordered_case_n = summary_df["caso_n"].drop_duplicates().tolist()
summary_df
# Out:
#             funcion   nombre_funcion metodo          nombre_metodo  dimension  \
# 0   goldstein_price  Goldstein-Price     de  Evolucion diferencial          2
# 1   goldstein_price  Goldstein-Price     ea    Algoritmo evolutivo          2
# 2   goldstein_price  Goldstein-Price    pso                    PSO          2
# 3   goldstein_price  Goldstein-Price     de  Evolucion diferencial          2
# 4   goldstein_price  Goldstein-Price     ea    Algoritmo evolutivo          2
# ..              ...              ...    ...                    ...        ...
# 85   six_hump_camel   Six-Hump Camel     ea    Algoritmo evolutivo          2
# 86   six_hump_camel   Six-Hump Camel    pso                    PSO          2
# 87   six_hump_camel   Six-Hump Camel     de  Evolucion diferencial          2
# 88   six_hump_camel   Six-Hump Camel     ea    Algoritmo evolutivo          2
# 89   six_hump_camel   Six-Hump Camel    pso                    PSO          2
#
#     n_corridas  mejor_valor  peor_valor  promedio_valor  mediana_valor  \
# 0          100     3.000000    3.000000        3.000000       3.000000
# 1          100     3.011752    4.336153        3.338019       3.220787
# 2          100     3.000000    3.000000        3.000000       3.000000
# 3          500     3.000000    3.000000        3.000000       3.000000
# 4          500     3.007420    4.336153        3.208080       3.098265
# ..         ...          ...         ...             ...            ...
# 85         500    -1.031556   -1.013471       -1.029222      -1.030392
# 86         500    -1.031628   -1.031628       -1.031628      -1.031628
# 87        1000    -1.031628   -1.031628       -1.031628      -1.031628
# 88        1000    -1.031585   -1.013471       -1.029417      -1.030093
# 89        1000    -1.031628   -1.031628       -1.031628      -1.031628
#
#     desviacion_valor  mejor_distancia_al_optimo  promedio_distancia_al_optimo  \
# 0       9.409453e-15               1.840240e-09                  6.059547e-09
# 1       3.697649e-01               6.059783e-03                  2.987153e-02
# 2       1.675337e-12               3.832762e-09                  2.783651e-08
# 3       9.812181e-15               1.005919e-09                  4.393659e-09
# 4       2.806074e-01               4.104958e-03                  2.191061e-02
# ..               ...                        ...                           ...
# 85      2.923234e-03               7.269088e-03                  1.005735e+00
# 86      6.143328e-14               3.521953e-07                  1.065953e+00
# 87      1.634599e-10               1.034882e-07                  7.987462e-01
# 88      2.347016e-03               7.269088e-03                  9.606496e-01
# 89      4.436990e-14               3.521953e-07                  1.110487e+00
#
#     promedio_evaluaciones  mediana_evaluaciones  promedio_iteraciones  \
# 0                  4840.0                4840.0                 120.0
# 1                  4840.0                4840.0                 120.0
# 2                  4840.0                4840.0                 120.0
# 3                  4840.0                4840.0                 120.0
# 4                  4840.0                4840.0                 120.0
# ..                    ...                   ...                   ...
# 85                 4840.0                4840.0                 120.0
# 86                 4840.0                4840.0                 120.0
# 87                 4840.0                4840.0                 120.0
# 88                 4840.0                4840.0                 120.0
# 89                 4840.0                4840.0                 120.0
#
#     mediana_iteraciones                caso                      caso_n
# 0                 120.0  Goldstein-Price 2D  Goldstein-Price 2D | n=100
# 1                 120.0  Goldstein-Price 2D  Goldstein-Price 2D | n=100
# 2                 120.0  Goldstein-Price 2D  Goldstein-Price 2D | n=100
# 3                 120.0  Goldstein-Price 2D  Goldstein-Price 2D | n=500
# 4                 120.0  Goldstein-Price 2D  Goldstein-Price 2D | n=500
# ..                  ...                 ...                         ...
# 85                120.0   Six-Hump Camel 2D   Six-Hump Camel 2D | n=500
# 86                120.0   Six-Hump Camel 2D   Six-Hump Camel 2D | n=500
# 87                120.0   Six-Hump Camel 2D  Six-Hump Camel 2D | n=1000
# 88                120.0   Six-Hump Camel 2D  Six-Hump Camel 2D | n=1000
# 89                120.0   Six-Hump Camel 2D  Six-Hump Camel 2D | n=1000
#
# [90 rows x 19 columns]

# %% [markdown]
# ## Tabla base para reporte

# %%
tabla_reporte = (
    summary_df[
        [
            "nombre_funcion",
            "dimension",
            "nombre_metodo",
            "n_corridas",
            "mejor_valor",
            "promedio_valor",
            "desviacion_valor",
            "promedio_distancia_al_optimo",
            "promedio_evaluaciones",
        ]
    ]
    .sort_values(["nombre_funcion", "dimension", "nombre_metodo"])
    .reset_index(drop=True)
)

tabla_reporte
# Out:
#      nombre_funcion  dimension          nombre_metodo  n_corridas  \
# 0   Goldstein-Price          2    Algoritmo evolutivo         100
# 1   Goldstein-Price          2    Algoritmo evolutivo         500
# 2   Goldstein-Price          2    Algoritmo evolutivo        1000
# 3   Goldstein-Price          2  Evolucion diferencial         100
# 4   Goldstein-Price          2  Evolucion diferencial         500
# ..              ...        ...                    ...         ...
# 85   Six-Hump Camel          2  Evolucion diferencial         500
# 86   Six-Hump Camel          2  Evolucion diferencial        1000
# 87   Six-Hump Camel          2                    PSO         100
# 88   Six-Hump Camel          2                    PSO         500
# 89   Six-Hump Camel          2                    PSO        1000
#
#     mejor_valor  promedio_valor  desviacion_valor  \
# 0      3.011752        3.338019      3.697649e-01
# 1      3.007420        3.208080      2.806074e-01
# 2      3.007420        3.199833      2.531059e-01
# 3      3.000000        3.000000      9.409453e-15
# 4      3.000000        3.000000      9.812181e-15
# ..          ...             ...               ...
# 85    -1.031628       -1.031628      2.036880e-10
# 86    -1.031628       -1.031628      1.634599e-10
# 87    -1.031628       -1.031628      1.343516e-13
# 88    -1.031628       -1.031628      6.143328e-14
# 89    -1.031628       -1.031628      4.436990e-14
#
#     promedio_distancia_al_optimo  promedio_evaluaciones
# 0                   2.987153e-02                 4840.0
# 1                   2.191061e-02                 4840.0
# 2                   2.152912e-02                 4840.0
# 3                   6.059547e-09                 4840.0
# 4                   4.393659e-09                 4840.0
# ..                           ...                    ...
# 85                  9.395323e-01                 4840.0
# 86                  7.987462e-01                 4840.0
# 87                  6.608334e-01                 4840.0
# 88                  1.065953e+00                 4840.0
# 89                  1.110487e+00                 4840.0
#
# [90 rows x 9 columns]

# %% [markdown]
# ## Mejores y peores casos

# %%
mejores_casos = runs_df.nsmallest(15, "mejor_valor")[
    ["caso", "nombre_metodo", "corrida", "mejor_valor", "distancia_al_optimo", "evaluaciones"]
]

peores_casos = runs_df.nlargest(15, "mejor_valor")[
    ["caso", "nombre_metodo", "corrida", "mejor_valor", "distancia_al_optimo", "evaluaciones"]
]

print("Mejores casos globales")
display(mejores_casos)
print("Peores casos globales")
display(peores_casos)
# Out:
# Mejores casos globales
#                     caso          nombre_metodo  corrida  mejor_valor  \
# 43200  Six-Hump Camel 2D  Evolucion diferencial        1    -1.031628
# 43206  Six-Hump Camel 2D  Evolucion diferencial        7    -1.031628
# 43218  Six-Hump Camel 2D  Evolucion diferencial       19    -1.031628
# 43227  Six-Hump Camel 2D  Evolucion diferencial       28    -1.031628
# 43228  Six-Hump Camel 2D  Evolucion diferencial       29    -1.031628
# 43236  Six-Hump Camel 2D  Evolucion diferencial       37    -1.031628
# 43237  Six-Hump Camel 2D  Evolucion diferencial       38    -1.031628
# 43245  Six-Hump Camel 2D  Evolucion diferencial       46    -1.031628
# 43246  Six-Hump Camel 2D  Evolucion diferencial       47    -1.031628
# 43254  Six-Hump Camel 2D  Evolucion diferencial       55    -1.031628
# 43255  Six-Hump Camel 2D  Evolucion diferencial       56    -1.031628
# 43258  Six-Hump Camel 2D  Evolucion diferencial       59    -1.031628
# 43263  Six-Hump Camel 2D  Evolucion diferencial       64    -1.031628
# 43264  Six-Hump Camel 2D  Evolucion diferencial       65    -1.031628
# 43267  Six-Hump Camel 2D  Evolucion diferencial       68    -1.031628
#
#        distancia_al_optimo  evaluaciones
# 43200             1.436594          4840
# 43206             1.436594          4840
# 43218             1.436594          4840
# 43227             1.436594          4840
# 43228             1.436594          4840
# 43236             1.436594          4840
# 43237             1.436594          4840
# 43245             1.436594          4840
# 43246             1.436594          4840
# 43254             1.436594          4840
# 43255             1.436594          4840
# 43258             1.436594          4840
# 43263             1.436594          4840
# 43264             1.436594          4840
# 43267             1.436594          4840
# Peores casos globales
#               caso nombre_metodo  corrida  mejor_valor  distancia_al_optimo  \
# 41678  Schwefel 3D           PSO       79   356.832102          1171.164607
# 41687  Schwefel 3D           PSO       88   356.832102          1171.164607
# 41696  Schwefel 3D           PSO       97   356.832102          1171.164607
# 41778  Schwefel 3D           PSO       79   356.832102          1171.164607
# 41787  Schwefel 3D           PSO       88   356.832102          1171.164607
# 41796  Schwefel 3D           PSO       97   356.832102          1171.164607
# 42778  Schwefel 3D           PSO       79   356.832102          1171.164607
# 42787  Schwefel 3D           PSO       88   356.832102          1171.164607
# 42796  Schwefel 3D           PSO       97   356.832102          1171.164607
# 41668  Schwefel 3D           PSO       69   236.876707          1023.174598
# 41677  Schwefel 3D           PSO       78   236.876707          1023.174598
# 41686  Schwefel 3D           PSO       87   236.876707          1023.174598
# 41695  Schwefel 3D           PSO       96   236.876707          1023.174598
# 41768  Schwefel 3D           PSO       69   236.876707          1023.174598
# 41777  Schwefel 3D           PSO       78   236.876707          1023.174598
#
#        evaluaciones
# 41678          7050
# 41687          7050
# 41696          7050
# 41778          7050
# 41787          7050
# 41796          7050
# 42778          7050
# 42787          7050
# 42796          7050
# 41668          7050
# 41677          7050
# 41686          7050
# 41695          7050
# 41768          7050
# 41777          7050

# %% [markdown]
# ## Ranking por caso
#
# Se prioriza valor promedio, luego cercania promedio al optimo y luego costo promedio en evaluaciones.

# %%
ranking_por_caso = (
    summary_df.sort_values(
        ["caso", "promedio_valor", "promedio_distancia_al_optimo", "promedio_evaluaciones"]
    )
    .groupby("caso", as_index=False)
    .first()[
        [
            "caso",
            "nombre_metodo",
            "promedio_valor",
            "promedio_distancia_al_optimo",
            "promedio_evaluaciones",
        ]
    ]
)

ranking_por_caso
# Out:
#                  caso          nombre_metodo  promedio_valor  \
# 0  Goldstein-Price 2D  Evolucion diferencial    3.000000e+00
# 1         Griewank 2D  Evolucion diferencial    2.150460e-03
# 2         Griewank 3D                    PSO    9.002913e-03
# 3        Rastrigin 2D  Evolucion diferencial    7.571831e-12
# 4        Rastrigin 3D  Evolucion diferencial    1.597214e-02
# 5       Rosenbrock 2D  Evolucion diferencial    3.604207e-13
# 6       Rosenbrock 3D  Evolucion diferencial    1.465712e-04
# 7         Schwefel 2D  Evolucion diferencial    2.545513e-05
# 8         Schwefel 3D  Evolucion diferencial    3.819315e-05
# 9   Six-Hump Camel 2D                    PSO   -1.031628e+00
#
#    promedio_distancia_al_optimo  promedio_evaluaciones
# 0                  4.393659e-09                 4840.0
# 1                  7.927933e-01                 7050.0
# 2                  4.826982e+00                 7050.0
# 3                  8.089109e-08                 4840.0
# 4                  4.741411e-03                 4840.0
# 5                  5.203915e-07                 4840.0
# 6                  1.036440e-02                 4840.0
# 7                  6.148978e-07                 7050.0
# 8                  2.265668e-04                 7050.0
# 9                  1.110487e+00                 4840.0

# %% [markdown]
# ## Figuras para reporte

# %%
method_colors = {
    "Algoritmo evolutivo": "#4C78A8",
    "PSO": "#F58518",
    "Evolucion diferencial": "#54A24B",
}

def get_figure_dir(function_name: str) -> Path:
    function_dir = FIGURES_DIR / function_name
    function_dir.mkdir(parents=True, exist_ok=True)
    return function_dir


def save_current_figure(filename: str, function_name: str | None = None) -> Path:
    path = (get_figure_dir(function_name) / filename) if function_name else (FIGURES_DIR / filename)
    plt.savefig(path, dpi=300, bbox_inches="tight")
    return path

# %% [markdown]
# ### 3. Distribuciones por metodo

# %%
fig, axes = plt.subplots(1, 2, figsize=(16, 5))
method_names = list(dict.fromkeys(runs_df["nombre_metodo"]))

for method_name in method_names:
    subset = runs_df[runs_df["nombre_metodo"] == method_name]
    color = method_colors.get(method_name, "#777777")
    axes[0].hist(subset["mejor_valor"], bins=20, alpha=0.5, label=method_name, color=color)
    axes[1].hist(subset["evaluaciones"], bins=20, alpha=0.5, label=method_name, color=color)

axes[0].set_title("Distribucion del mejor valor")
axes[0].set_xlabel("Mejor valor")
axes[0].set_ylabel("Frecuencia")
axes[0].grid(alpha=0.3)

axes[1].set_title("Distribucion de evaluaciones")
axes[1].set_xlabel("Evaluaciones")
axes[1].set_ylabel("Frecuencia")
axes[1].grid(alpha=0.3)

axes[0].legend()
axes[1].legend()
plt.tight_layout()
fig_path = save_current_figure("03_histogramas_por_metodo.png")
plt.show()
fig_path
# Out:
# WindowsPath('C:/Carlos/Uni/Algortimos/trabajos/trabajo_1/trabajo_carlos/1. optimizacion_numerica/assets/heuristicos/images/03_histogramas_por_metodo.png')

# %% [markdown]
# ### 4. Comparacion por caso

# %% [markdown]
# ### 5. Graficas de convergencia
#
# Estas curvas requieren que cada archivo JSON de corridas incluya `best_values_history`. Si todavia no aparece ese campo, hay que volver a ejecutar el generador.

# %%
def load_json_runs() -> list[dict]:
    all_rows = []
    for json_path in run_json_files:
        with json_path.open("r", encoding="utf-8") as file:
            rows = json.load(file)
        for row in rows:
            row["source_file"] = json_path.name
            all_rows.append(row)
    return all_rows

json_runs = load_json_runs()
has_histories = any("best_values_history" in row for row in json_runs)
print("Hay historiales de convergencia disponibles:", has_histories)
# Out:
# Hay historiales de convergencia disponibles: True

# %%
if has_histories:
    convergence_rows = [
        row for row in json_runs
        if "best_values_history" in row and row["best_values_history"]
    ]

    funciones = sorted({str(row["nombre_funcion"]).lower() for row in convergence_rows})

    for funcion in funciones:
        fig, axes = plt.subplots(1, 2, figsize=(14, 5))
        dimensiones = [2, 3]

        for ax, dim in zip(axes, dimensiones):
            case_rows = [
                row for row in convergence_rows
                if str(row["nombre_funcion"]).lower() == funcion
                and int(row["dimension"]) == dim
            ]

            if not case_rows:
                ax.set_title(f"{funcion.capitalize()} {dim}D - sin datos")
                ax.axis("off")
                continue

            for method_name in sorted({row["nombre_metodo"] for row in case_rows}):
                method_histories = [
                    np.asarray(row["best_values_history"], dtype=float)
                    for row in case_rows
                    if row["nombre_metodo"] == method_name
                ]

                min_length = min(len(history) for history in method_histories)
                aligned = np.vstack([history[:min_length] for history in method_histories])
                mean_history = aligned.mean(axis=0)

                color = method_colors.get(method_name, "#777777")
                ax.plot(mean_history, label=method_name, linewidth=2, color=color)

            ax.set_title(f"Convergencia - {funcion.capitalize()} {dim}D")
            ax.set_xlabel("Iteracion")
            ax.set_ylabel("Mejor valor medio")
            ax.set_yscale("symlog")
            ax.grid(alpha=0.3)
            ax.legend()

        plt.tight_layout()
        fig_path = save_current_figure(f"convergencia_{funcion}_2d_3d.png", function_name=funcion)
        plt.show()
        display(fig_path)
else:
    print("No se encontraron historiales.")
# Out:
# WindowsPath('C:/Carlos/Uni/Algortimos/trabajos/trabajo_1/trabajo_carlos/1. optimizacion_numerica/assets/heuristicos/images/goldstein-price/convergencia_goldstein-price_2d_3d.png')
# WindowsPath('C:/Carlos/Uni/Algortimos/trabajos/trabajo_1/trabajo_carlos/1. optimizacion_numerica/assets/heuristicos/images/griewank/convergencia_griewank_2d_3d.png')
# WindowsPath('C:/Carlos/Uni/Algortimos/trabajos/trabajo_1/trabajo_carlos/1. optimizacion_numerica/assets/heuristicos/images/rastrigin/convergencia_rastrigin_2d_3d.png')
# WindowsPath('C:/Carlos/Uni/Algortimos/trabajos/trabajo_1/trabajo_carlos/1. optimizacion_numerica/assets/heuristicos/images/rosenbrock/convergencia_rosenbrock_2d_3d.png')
# WindowsPath('C:/Carlos/Uni/Algortimos/trabajos/trabajo_1/trabajo_carlos/1. optimizacion_numerica/assets/heuristicos/images/schwefel/convergencia_schwefel_2d_3d.png')
# WindowsPath('C:/Carlos/Uni/Algortimos/trabajos/trabajo_1/trabajo_carlos/1. optimizacion_numerica/assets/heuristicos/images/six-hump camel/convergencia_six-hump camel_2d_3d.png')

# %% [markdown]
# ## Exportables utiles para el reporte

# %%
tabla_reporte_path = FIGURES_DIR / "tabla_resumen_heuristicos.csv"
ranking_path = FIGURES_DIR / "ranking_por_caso.csv"
mejores_path = FIGURES_DIR / "mejores_casos.csv"
peores_path = FIGURES_DIR / "peores_casos.csv"

tabla_reporte.to_csv(tabla_reporte_path, index=False, encoding="utf-8")
ranking_por_caso.to_csv(ranking_path, index=False, encoding="utf-8")
mejores_casos.to_csv(mejores_path, index=False, encoding="utf-8")
peores_casos.to_csv(peores_path, index=False, encoding="utf-8")

print("Archivos exportados:")
print("-", tabla_reporte_path)
print("-", ranking_path)
print("-", mejores_path)
print("-", peores_path)
# Out:
# Archivos exportados:
# - C:\Carlos\Uni\Algortimos\trabajos\trabajo_1\trabajo_carlos\1. optimizacion_numerica\assets\heuristicos\images\tabla_resumen_heuristicos.csv
# - C:\Carlos\Uni\Algortimos\trabajos\trabajo_1\trabajo_carlos\1. optimizacion_numerica\assets\heuristicos\images\ranking_por_caso.csv
# - C:\Carlos\Uni\Algortimos\trabajos\trabajo_1\trabajo_carlos\1. optimizacion_numerica\assets\heuristicos\images\mejores_casos.csv
# - C:\Carlos\Uni\Algortimos\trabajos\trabajo_1\trabajo_carlos\1. optimizacion_numerica\assets\heuristicos\images\peores_casos.csv

# %%
# Graficas de barras del mejor valor promedio por metodo:
# izquierda = 2D, derecha = 3D

data_2d = summary_df[
    summary_df["caso_n"].astype(str).str.contains("2d", case=False, na=False)
].copy()

data_3d = summary_df[
    summary_df["caso_n"].astype(str).str.contains("3d", case=False, na=False)
].copy()

resumen_2d = (
    data_2d.groupby("nombre_metodo", as_index=False)["promedio_valor"]
    .mean()
    .sort_values("promedio_valor")
)

resumen_3d = (
    data_3d.groupby("nombre_metodo", as_index=False)["promedio_valor"]
    .mean()
    .sort_values("promedio_valor")
)

valor_optimo_2d = 0
valor_optimo_3d = 0

fig, axes = plt.subplots(1, 2, figsize=(16, 4), sharey=False)

colors_2d = [method_colors.get(name, "#777777") for name in resumen_2d["nombre_metodo"]]
colors_3d = [method_colors.get(name, "#777777") for name in resumen_3d["nombre_metodo"]]

axes[0].bar(resumen_2d["nombre_metodo"], resumen_2d["promedio_valor"], color=colors_2d)
axes[0].axhline(valor_optimo_2d, color="red", linestyle="--", linewidth=1.8, label="Valor optimo")
axes[0].set_title("Mejor valor promedio por metodo en 2D")
axes[0].set_xlabel("Metodo")
axes[0].set_ylabel("Mejor valor promedio")
axes[0].tick_params(axis="x", rotation=20)
axes[0].grid(axis="y", alpha=0.3)
axes[0].legend()

axes[1].bar(resumen_3d["nombre_metodo"], resumen_3d["promedio_valor"], color=colors_3d)
axes[1].axhline(valor_optimo_3d, color="red", linestyle="--", linewidth=1.8, label="Valor optimo")
axes[1].set_title("Mejor valor promedio por metodo en 3D")
axes[1].set_xlabel("Metodo")
axes[1].set_ylabel("Mejor valor promedio")
axes[1].tick_params(axis="x", rotation=20)
axes[1].grid(axis="y", alpha=0.3)
axes[1].legend()

plt.tight_layout()
fig_path = save_current_figure("mejor_valor_promedio_por_metodo_2d_3d.png")
plt.show()
fig_path
# Out:
# WindowsPath('C:/Carlos/Uni/Algortimos/trabajos/trabajo_1/trabajo_carlos/1. optimizacion_numerica/assets/heuristicos/images/mejor_valor_promedio_por_metodo_2d_3d.png')

# %%
# Grafica completa:
# izquierda = 2D, derecha = 3D
# eje x = numero de corridas (100, 500, 1000)
# barras = metodo
# y = promedio_valor

plot_df = summary_df.copy()

plot_df["dimension"] = plot_df["caso_n"].astype(str).str.extract(r"(2d|3d)", expand=False)
plot_df["n_corridas"] = pd.to_numeric(
    plot_df["caso_n"].astype(str).str.extract(r"n(\d+)", expand=False),
    errors="coerce"
)

plot_df["metodo_plot"] = (
    plot_df["nombre_metodo"]
    .astype(str)
    .str.lower()
    .replace({
        "evolucion diferencial": "DE",
        "algoritmo evolutivo": "AG",
        "pso": "PSO",
        "de": "DE",
        "ea": "AG",
        "ag": "AG"
    })
)

plot_df = plot_df.dropna(subset=["dimension", "n_corridas", "promedio_valor"])
plot_df["n_corridas"] = plot_df["n_corridas"].astype(int)

fig, axes = plt.subplots(1, 2, figsize=(16, 4), sharey=False)

orden_n = [100, 500, 1000]
orden_metodos = ["DE", "AG", "PSO"]
colores = {
    "DE": "#54A24B",
    "AG": "#4C78A8",
    "PSO": "#F58518"
}

for ax, dim in zip(axes, ["2d", "3d"]):
    data_dim = plot_df[plot_df["dimension"] == dim].copy()

    pivot_vals = (
        data_dim.pivot_table(
            index="n_corridas",
            columns="metodo_plot",
            values="promedio_valor",
            aggfunc="mean"
        )
        .reindex(index=orden_n, columns=orden_metodos)
    )

    pivot_vals.plot(
        kind="bar",
        ax=ax,
        width=0.8,
        color=[colores.get(col, "#777777") for col in pivot_vals.columns]
    )

    ax.axhline(0, color="red", linestyle="--", linewidth=1.5, label="Valor optimo")
    ax.set_title(f"Mejor valor promedio por metodo en {dim.upper()}")
    ax.set_xlabel("Numero de corridas")
    ax.set_ylabel("Mejor valor promedio")
    ax.tick_params(axis="x", rotation=0)
    ax.grid(axis="y", alpha=0.3)
    ax.legend(title="Metodo")

plt.tight_layout()
fig_path = save_current_figure("mejor_valor_promedio_por_metodo_2d_3d_y_corridas.png")
plt.show()
fig_path
# Out:
# WindowsPath('C:/Carlos/Uni/Algortimos/trabajos/trabajo_1/trabajo_carlos/1. optimizacion_numerica/assets/heuristicos/images/mejor_valor_promedio_por_metodo_2d_3d_y_corridas.png')

# %%
print(summary_df["dimension"].drop_duplicates().tolist())
print(summary_df["n_corridas"].drop_duplicates().tolist())
print(summary_df["nombre_metodo"].drop_duplicates().tolist())
# Out:
# [2, 3]
# [100, 500, 1000]
# ['Evolucion diferencial', 'Algoritmo evolutivo', 'PSO']

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

funciones = sorted(summary_df["nombre_funcion"].dropna().astype(str).unique())

orden_n = [100, 500, 1000]
orden_metodos = ["DE", "AG", "PSO"]
colores = {
    "DE": "#54A24B",
    "AG": "#4C78A8",
    "PSO": "#F58518"
}

for funcion in funciones:
    plot_df = summary_df[
        summary_df["nombre_funcion"].astype(str).str.lower() == funcion.lower()
    ].copy()

    plot_df["metodo_plot"] = (
        plot_df["nombre_metodo"]
        .astype(str)
        .str.lower()
        .replace({
            "evolucion diferencial": "DE",
            "algoritmo evolutivo": "AG",
            "pso": "PSO",
            "de": "DE",
            "ea": "AG",
            "ag": "AG"
        })
    )

    plot_df = plot_df.dropna(subset=["dimension", "n_corridas", "mediana_valor"]).copy()
    plot_df["n_corridas"] = pd.to_numeric(plot_df["n_corridas"], errors="coerce")
    plot_df = plot_df.dropna(subset=["n_corridas"])
    plot_df["n_corridas"] = plot_df["n_corridas"].astype(int)

    fig, axes = plt.subplots(1, 2, figsize=(16, 4.5), sharey=False)

    for ax, dim, titulo in zip(axes, [2, 3], ["2D", "3D"]):
        data_dim = plot_df[plot_df["dimension"] == dim].copy()

        pivot_vals = (
            data_dim.pivot_table(
                index="n_corridas",
                columns="metodo_plot",
                values="mediana_valor",
                aggfunc="mean"
            )
            .reindex(index=orden_n, columns=orden_metodos)
        )

        pivot_vals.plot(
            kind="bar",
            ax=ax,
            width=0.75,
            color=[colores.get(col, "#777777") for col in pivot_vals.columns]
        )

        ax.relim()
        ax.autoscale_view()
        
        ymin, ymax = ax.get_ylim()
        if ymin > 0:
            ymin = 0
            
        # Si el valor máximo es microscópico (ej. menor a 0.05), forzamos un zoom limpio 
        # para que el eje Y no exagere un espacio vacío tan grande hacia arriba.
        if ymax < 0.05:
            ax.set_ylim(ymin, max(ymax * 1.5, 0.001))
        else:
            ax.set_ylim(ymin, ymax * 1.15)

        ax.axhline(0, color="red", linestyle="--", linewidth=1.5, label="Valor optimo")
        ax.set_title(f"{funcion.capitalize()} - {titulo}", fontsize=12)
        ax.set_xlabel("Numero de corridas", fontsize=10)
        ax.set_ylabel("Mediana del valor final", fontsize=10)
        ax.tick_params(axis="x", rotation=0)
        ax.grid(axis="y", alpha=0.3)
        ax.legend(title="Metodo", frameon=True)

        # CORRECCIÓN DE ETIQUETAS: Usar notación científica obligatoria si los números son pequeños
        for container in ax.containers:
            for bar, val in zip(container, container.datavalues):
                if np.isnan(val):
                    continue
                # Si el valor es muy cercano a 0, mostramos notación científica para que no salga "0.00"
                label_text = f"{val:.2e}" if val < 0.01 else f"{val:.2f}"
                ax.annotate(
                    label_text,
                    xy=(bar.get_x() + bar.get_width() / 2, bar.get_height()),
                    xytext=(0, 3),  # 3 puntos de desplazamiento vertical
                    textcoords="offset points",
                    ha="center", va="bottom", fontsize=7, rotation=0
                )

    plt.tight_layout()
    fig_path = save_current_figure(f"{funcion.lower()}_2d_3d_corridas.png", function_name=funcion.lower())
    plt.show()
    print(fig_path)
# Out:
# C:\Carlos\Uni\Algortimos\trabajos\trabajo_1\trabajo_carlos\1. optimizacion_numerica\assets\heuristicos\images\goldstein-price\goldstein-price_2d_3d_corridas.png
# C:\Carlos\Uni\Algortimos\trabajos\trabajo_1\trabajo_carlos\1. optimizacion_numerica\assets\heuristicos\images\griewank\griewank_2d_3d_corridas.png
# C:\Carlos\Uni\Algortimos\trabajos\trabajo_1\trabajo_carlos\1. optimizacion_numerica\assets\heuristicos\images\rastrigin\rastrigin_2d_3d_corridas.png
# C:\Carlos\Uni\Algortimos\trabajos\trabajo_1\trabajo_carlos\1. optimizacion_numerica\assets\heuristicos\images\rosenbrock\rosenbrock_2d_3d_corridas.png
# C:\Carlos\Uni\Algortimos\trabajos\trabajo_1\trabajo_carlos\1. optimizacion_numerica\assets\heuristicos\images\schwefel\schwefel_2d_3d_corridas.png
# C:\Carlos\Uni\Algortimos\trabajos\trabajo_1\trabajo_carlos\1. optimizacion_numerica\assets\heuristicos\images\six-hump camel\six-hump camel_2d_3d_corridas.png
