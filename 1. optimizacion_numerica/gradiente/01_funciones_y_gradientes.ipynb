# %% [markdown]
# - implementación de las 6 funciones objetivo
# - gradientes para las que usarás con descenso por gradiente
# - pruebas rápidas de que cada función corre en 2D y 3D
# - pequeñas visualizaciones de las funciones 2D si quieres validar

# %% [markdown]
# # 1 Implementacion de las funciones objetivo
