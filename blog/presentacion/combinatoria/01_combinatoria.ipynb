# %% [markdown]
# ---
# title: "Optimizacion combinatoria"
# format:
#   html:
#     toc: true
# ---
#
# # Objetivo
#
# Esta pagina resume la parte de optimizacion combinatoria del proyecto. Sirve como version presentable del trabajo, separada de los notebooks originales donde hiciste el proceso completo.

# %% [markdown]
# ## Lo que se trabajo
#
# - Preparacion y limpieza de los datos.
# - Formulacion del problema combinatorio.
# - Analisis de resultados y comportamiento de la solucion.

# %% [markdown]
# ## Resultados clave
#
# Aqui puedes contar de forma breve que solucion se obtuvo, por que fue relevante y cuales fueron los principales hallazgos del experimento o la heuristica usada.

# %% [markdown]
# ## Cuadernos de soporte
#
# - [Construccion inicial del grafo](../../notebooks/combinatoria/00_construccion_grafo_inicial.ipynb)
# - [Preprocesamiento](../../notebooks/combinatoria/01_preprocesamiento.ipynb)
# - [Optimizacion](../../notebooks/combinatoria/02_optimizacion.ipynb)
# - [Resultados finales](../../notebooks/combinatoria/03_resultados_finales.ipynb)
